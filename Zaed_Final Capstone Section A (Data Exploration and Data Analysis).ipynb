# %%
# Import necessary libraries

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Importing the dataset

data = pd.read_csv("employee_dataset.csv")

# %% [markdown]
# i. Display the number of variables/attributes available in the dataset.

# %%
# Display the number of variables/attributes

num_variables = data.shape[1]
print("Number of variables/attributes:", num_variables)
# Out:
# Number of variables/attributes: 24

# %%
# Find the dimension number of this dataset

data.head()
# Out:
#    Age     BusinessTravel  MonthlyIncome  JobSatisfaction  Bonus  \
# 0   41      Travel_Rarely           5993                4  17979
# 1   49  Travel_Frequently           5130                2  20520
# 2   37      Travel_Rarely           2090                3   6270
# 3   33  Travel_Frequently           2909                3   8727
# 4   27      Travel_Rarely           3468                2  10404
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
#
#    EmployeeCount  ...                JobRole  MaritalStatus PerformanceRating  \
# ...

# %% [markdown]
# ii. Find the dimension number of this dataset

# %%
# Look into the data type of this dataset

data.dtypes
# Out:
# Age                         int64
# BusinessTravel             object
# MonthlyIncome               int64
# JobSatisfaction             int64
# Bonus                       int64
# Department                 object
# DistanceFromHome            int64
# Education                   int64
# EducationField             object
# EmployeeCount               int64
# EmployeeNumber              int64
# EnvironmentSatisfaction     int64
# Gender                     object
# JobLevel                    int64
# JobRole                    object
# MaritalStatus              object
# PerformanceRating           int64
# StockOptionLevel            int64
# TrainingTimesLastYear       int64
# WorkLifeBalance             int64
# YearsAtCompany              int64
# YearsSinceLastPromotion     int64
# OverTime                   object
# Attrition                  object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1470 non-null   int64
#  1   BusinessTravel           1470 non-null   object
#  2   MonthlyIncome            1470 non-null   int64
#  3   JobSatisfaction          1470 non-null   int64
#  4   Bonus                    1470 non-null   int64
#  5   Department               1470 non-null   object
#  6   DistanceFromHome         1470 non-null   int64
#  7   Education                1470 non-null   int64
#  8   EducationField           1470 non-null   object
#  9   EmployeeCount            1470 non-null   int64
#  10  EmployeeNumber           1470 non-null   int64
#  11  EnvironmentSatisfaction  1470 non-null   int64
#  12  Gender                   1470 non-null   object
#  13  JobLevel                 1470 non-null   int64
# ...

# %%
data.describe()
# Out:
#                Age  MonthlyIncome  JobSatisfaction         Bonus  \
# count  1470.000000    1470.000000      1470.000000   1470.000000
# mean     36.923810    6502.931293         2.728571  20479.501361
# std       9.135373    4707.956783         1.102846  15066.272964
# min      18.000000    1009.000000         1.000000   3027.000000
# 25%      30.000000    2911.000000         2.000000   9333.750000
# 50%      36.000000    4919.000000         3.000000  15484.500000
# 75%      43.000000    8379.000000         4.000000  26103.750000
# max      60.000000   19999.000000         4.000000  79892.000000
#
#        DistanceFromHome    Education  EmployeeCount  EmployeeNumber  \
# count       1470.000000  1470.000000         1470.0     1470.000000
# mean           9.192517     2.912925            1.0     1024.865306
# std            8.106864     1.024165            0.0      602.024335
# min            1.000000     1.000000            1.0        1.000000
# ...

# %%
data.describe(include='all')
# Out:
#                 Age BusinessTravel  MonthlyIncome  JobSatisfaction  \
# count   1470.000000           1470    1470.000000      1470.000000
# unique          NaN              3            NaN              NaN
# top             NaN  Travel_Rarely            NaN              NaN
# freq            NaN           1043            NaN              NaN
# mean      36.923810            NaN    6502.931293         2.728571
# std        9.135373            NaN    4707.956783         1.102846
# min       18.000000            NaN    1009.000000         1.000000
# 25%       30.000000            NaN    2911.000000         2.000000
# 50%       36.000000            NaN    4919.000000         3.000000
# 75%       43.000000            NaN    8379.000000         4.000000
# max       60.000000            NaN   19999.000000         4.000000
#
#                Bonus              Department  DistanceFromHome    Education  \
# count    1470.000000                    1470       1470.000000  1470.000000
# ...

# %% [markdown]
# iii. Display the average of these attributes: 'Age', 'Monthly Income', and 'Years at Company'.

# %%
# Calculate the average

avg_norm_loss = data["Age"].astype("float").mean()
print("Average of Age: {:.2f}".format(avg_norm_loss))

avg_norm_loss = data["MonthlyIncome"].astype("float").mean()
print("Average of Monthly Income: {:.2f}".format(avg_norm_loss))

avg_norm_loss = data["YearsAtCompany"].astype("float").mean()
print("Average of Years at Company: {:.2f}".format(avg_norm_loss))
# Out:
# Average of Age: 36.92
# Average of Monthly Income: 6502.93
# Average of Years at Company: 7.01

# %% [markdown]
# iv. Find the minimum and maximum 'Monthly Income'

# %%
# Find the minimum and maximum 'Monthly Income'

min_monthly_income = data['MonthlyIncome'].min()
max_monthly_income = data['MonthlyIncome'].max()

print("Minimum Monthly Income:", min_monthly_income)
print("Maximum Monthly Income:", max_monthly_income)
# Out:
# Minimum Monthly Income: 1009
# Maximum Monthly Income: 19999

# %% [markdown]
# v. Provide graphical visualization by plotting Histogram of 'Monthly Income vs. staff numbers'

# %%
# Plot histogram

plt.figure(figsize=(10, 6))
plt.hist(data['MonthlyIncome'], bins=20, color='green', edgecolor='black', alpha=0.7)
plt.xlabel('Monthly Income')
plt.ylabel('Number of Employees')
plt.title('Monthly Income vs. Number of Employees')
plt.grid(True)
plt.show()

# %% [markdown]
# vi. Provide graphical Visualization of the distribution between 'Year at Company' and 'Monthly Income' using the scatter plot

# %%
# Plot scatter plot

plt.figure(figsize=(10, 6))
plt.scatter(data['YearsAtCompany'], data['MonthlyIncome'], color='orange', alpha=0.7)
plt.xlabel('Years at Company')
plt.ylabel('Monthly Income')
plt.title('Distribution between Years at Company and Monthly Income')
plt.grid(True)
plt.show()

# %% [markdown]
# vii. Find the correlation between 'Years at Company' and 'Monthly Income'

# %%
# Find the correlation between 'Years at Company' and 'Monthly Income'

correlation = data['YearsAtCompany'].corr(data['MonthlyIncome'])
print("Correlation between Years at Company and Monthly Income:", correlation)
# Out:
# Correlation between Years at Company and Monthly Income: 0.5142848257331968

# %% [markdown]
# viii. Based on findings, discuss briefly

# %% [markdown]
# a) Range of monthly income at Company A.
#
# Upon analysis of the dataset, it's observed that the range of monthly income at Company A spans from the lowest reported income value of 1,009 to the highest, 19,999. The numerical ranges vary depending on the variables and attributes such as job roles and years at the company. In particular, summary statistics such as the minimum and maximum monthly income values provide insight into employees' overall range of income levels. Visualizations such as histograms or scatter plots can also help identify the spread of income values and any potential outliers.

# %% [markdown]
# b) Most and Least Frequent monthly income values at Company A.
#
# The histogram depicting 'Monthly Income versus Number of Employees' suggests that the highest frequency of monthly income falls within the 2,500 range, while the lowest frequency is observed in the 15,000 range.

# %% [markdown]
# c) Discuss your observation on the distribution of the monthly income values.
#
# Based on analysis of both the histogram and scatterplot, it's evident that there exists a positive correlation between the duration of employment at Company A and the corresponding monthly income. Notably, most employees stay with the company for less than ten years. However, as the total tenure extends, monthly payment generally follows an upward trend, particularly noticeable beyond approximately 20 years of service. These trends align with our expectations, as longer-serving employees typically accumulate more experience, which often translates to higher earning potential. This observation underscores the intuitive notion that income tends to increase with employees' tenure and accumulated experience.

# %% [markdown]
# d) Is there a linear relationship between monthly income and employees' years at the company?
#
# Yes. The analysis implies a positive correlation rather than explicitly addressing linearity. While a positive correlation indicates that as one variable increases, the other tends to grow, it doesn't necessarily imply a strictly linear relationship. A linear relationship would mean that the change in monthly income is directly proportional to the change in years at the company. A closer to 1 or -1 correlation coefficient would indicate a stronger linear relationship. However, the provided analysis primarily focuses on the positive correlation and the general trend observed rather than explicitly addressing linearity.
